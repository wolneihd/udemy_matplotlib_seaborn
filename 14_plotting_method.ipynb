# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

# %%
data = [x * 10 for x in range(10)]
labels = [f'{x}!' for x in range(10)]

# %%
plt.plot(data)
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# cria 01 quadro geral
fig = plt.figure()
# cria no geral um sub_plot
ax = fig.add_subplot()
ax.plot(data)
ax.set_title('Title SubPlot')
fig.suptitle('Main Title')
# Out:
# Text(0.5, 0.98, 'Main Title')
